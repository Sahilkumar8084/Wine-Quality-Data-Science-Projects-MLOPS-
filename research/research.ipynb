# %%
print("sfgjdfg")
# Out:
# sfgjdfg

# %%
print("lsjfngfdG")
# Out:
# lsjfngfdG

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations 
def add(a:int,b:int):
    return a+b

# %%
add(5,6)
# Out:
# 11

# %%
add(5.6,1.2)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 add(5.6,1.2)
#
# File d:\mlops\Wine-Quality-Data-Science-Projects-MLOPS-\venv\lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument a of type <class 'float'> to <function add at 0x000001C2078F75B0> does not match annotation type <class 'int'>

# %% [markdown]
# ### <@Ensure_annotations> Iska use isliye kiya hai taaki agar function mein galat data type pass ho, toh ye turant error de de (Runtime Validation).
